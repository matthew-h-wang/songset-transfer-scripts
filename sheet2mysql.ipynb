# %%
pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script dotenv.exe is installed in 'C:\Users\mail4\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from os.path import join, dirname
from dotenv import load_dotenv

load_dotenv(".env")

# Database Env
HOST = os.environ.get("HOST")
PORT = os.environ.get("PORT")
DB_USER = os.environ.get("DB_USER")
DB_PASSWORD = os.environ.get("DB_PASSWORD")
DB_SCHEMA = os.environ.get("DB_SCHEMA")

# Set app user and band
USER_ID = os.environ.get("USER_ID")
BAND_ID = os.environ.get("BAND_ID")

# Start and end dates for sets to update (leftmost and rightmost column header)
FIRST_SET = '7/4/2021'
LAST_SET = '9/17/2023'

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in c:\users\mail4\appdata\roaming\python\python311\site-packages (8.1.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in c:\users\mail4\appdata\roaming\python\python311\site-packages (from mysql-connector-python) (4.21.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\mail4\appdata\roaming\python\python311\site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\mail4\appdata\roaming\python\python311\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mail4\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mail4\appdata\roaming\python\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mail4\appdata\roaming\python\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mail4\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
import pandas as pd
import numpy as np

# %%
#data.csv has a particular format, with columns being sets and rows being songs:
# Most of the grid indicates which songs were in which sets (perhaps indicated by an X, a number, or some other text)
# Other columns like ARTIST and Notes give additional info on songs
 
# Song   ... ARTIST , Notes, ...  DATE_1, DATE_2, DATE_3,...
# Song_1 ... ArtistA, Blah , ...  X     ,       , 2     ,...
# Song_2 ... ArtistB, Yadda, ...  1     ,      X,       ,...

df = pd.read_csv("data.csv", sep=",", dtype=str,
                skipinitialspace=True, index_col="Song")

# %%
# Connect to server
def get_cnx():
    return mysql.connector.connect(
        host=HOST,
        port=PORT,
        user=DB_USER,
        password=DB_PASSWORD,
        database=DB_SCHEMA)

# %% [markdown]
# # Create songs in database with certain content

# %%
song_ids = {}
cnx = get_cnx()
try :
    for title, row in df.iterrows():
        
        # Get a cursor
        cur = cnx.cursor(prepared=True)
        # Check to see if song already exists
        cur.execute("""SELECT song_id FROM song
                        WHERE title = %s AND band_id = %s LIMIT 1""", (title,BAND_ID))
        rows = cur.fetchall()
        if rows:
            # save song_id
            song_ids[title] = rows[0][0]
            print(title, "already exists with song_id", rows[0][0])
        else :
            # Parse relevant data
            artist = row['ARTIST']
            if pd.isnull(artist):
                artist = ""
            notes = row['Notes']
            if pd.isnull(notes):
                notes = ""
            tags = []
    
            
            if "hymn" in artist.lower() or "hymn" in notes.lower():
                tags.append("Hymn")
            if "advent" in notes.lower():
                tags.append("Advent")
            if "christmas" in notes.lower():
                tags.append("Christmas")
            if "easter" in notes.lower():
                tags.append("Easter")
            if "lent" in notes.lower():
                tags.append("Lent")
            if "good friday" in notes.lower():
                tags.append("Good Friday")
            if "palm" in notes.lower():
                tags.append("Palm Sunday")
        
            # Execute a query to create the song
            cur.execute("""INSERT INTO song 
                        (title, artist, tags, notes, creator_id, band_id)
                        VALUES (%s, %s, %s, %s, %s, %s)""",
                       (title, artist, ",".join(tags), notes, USER_ID, BAND_ID))
            # Save the song_id for later
            song_ids[title] = cur.lastrowid
            print(title, "added with song_id", cur.lastrowid)

        # Make sure data is committed to the database
        cnx.commit()
        cur.close()
except Exception as e:
    print(repr(e))
finally:
    # Close connection
    cnx.close()
# Out:
# Cornerstone added with song_id 644
# This I Believe (The Creed) added with song_id 645
# Goodness of God added with song_id 646
# Death Was Arrested added with song_id 647
# Behold the Lamb (Communion) added with song_id 648
# Great Are You Lord added with song_id 649
# Dance Again added with song_id 650
# The Lion and the Lamb added with song_id 651
# Living Hope added with song_id 652
# Way Maker added with song_id 653
# Mighty To Save added with song_id 654
# The Lord's Prayer (It's Yours) added with song_id 655
# Build My Life added with song_id 656
# In Christ Alone added with song_id 657
# Shout to the Lord added with song_id 658
# Take My Life (and Let It Be) added with song_id 659
# I Love To Tell The Story added with song_id 660
# Purify My Heart (Psalm 19) added with song_id 661
# Lord I Need You added with song_id 662
# The Solid Rock added with song_id 663
# Your Will Be Done added with song_id 664
# Everlasting God added with song_id 665
# Indescribable added with song_id 666
# God So Loved added with song_id 667
# Hosanna (I See The King of Glory) added with song_id 668
# Our God added with song_id 669
# Build Your Kingdom Here added with song_id 670
# Facing a Task Unfinished added with song_id 671
# Let it be so with your church added with song_id 672
# The Greatest Commandment added with song_id 673
# Your Grace Is Enough added with song_id 674
# Days of Elijah added with song_id 675
# Agnus Dei  added with song_id 676
# O Glorious Day added with song_id 677
# You Are My King (Amazing Love) added with song_id 678
# I Need Thee Every Hour added with song_id 679
# Forever (We Sing Hallelujah) added with song_id 680
# How Great Is Our God added with song_id 681
# Open The Eyes Of My Heart added with song_id 682
# O For A Thousand Tongues added with song_id 683
# The Blessing added with song_id 684
# Our God Is With Us added with song_id 685
# Forever Reign added with song_id 686
# Tis So Sweet to Trust in Jesus added with song_id 687
# 10,000 Reasons added with song_id 688
# O Praise The Name (Anástasis) added with song_id 689
# All Creatures of Our God and King added with song_id 690
# Is He Worthy added with song_id 691
# Egypt added with song_id 692
# House Of The Lord added with song_id 693
# Better is One Day added with song_id 694
# Savior Like a Shepherd Lead Us added with song_id 695
# We Will Feast In The House of Zion added with song_id 696
# Graves into Gardens added with song_id 697
# Jesus Paid it All added with song_id 698
# O Come to the Altar added with song_id 699
# Nothing But The Blood added with song_id 700
# Create In Me A clean heart added with song_id 701
# How Deep The Father's Love added with song_id 702
# His Mercy is More added with song_id 703
# Come Thou Fount added with song_id 704
# This Time I Will Bring Praise added with song_id 705
# Never See the End added with song_id 706
# Blessed Be Your Name added with song_id 707
# It Is Well with My Soul added with song_id 708
# As The Deer added with song_id 709
# King of Kings added with song_id 710
# This is Amazing Grace added with song_id 711
# He Will Hold Me Fast added with song_id 712
# Reckless Love added with song_id 713
# Great Is Thy Faithfulness added with song_id 714
# A Mighty Fortress  added with song_id 715
# Lord of Hosts (Psalm 46) added with song_id 716
# Broken Vessels (Amazing Grace) added with song_id 717
# Hosanna (Praise Is Rising) added with song_id 718
# What A Beautiful Name added with song_id 719
# Revelation Song added with song_id 720
# Table of Plenty added with song_id 721
# From The Inside Out added with song_id 722
# Good Good Father added with song_id 723
# The Church's One Foundation added with song_id 724
# All The People Said Amen added with song_id 725
# Shine Jesus Shine added with song_id 726
# Oceans added with song_id 727
# Who You Say I Am added with song_id 728
# Grace Greater Than All Our Sin added with song_id 729
# Amazing Grace (My Chains Are Gone) added with song_id 730
# Rock of ages added with song_id 731
# Same God added with song_id 732
# Do It Again added with song_id 733
# Standing on the Promises added with song_id 734
# Jesus Loves Even Me added with song_id 735
# Be Thou My Vision added with song_id 736
# Make Me A Blessing added with song_id 737
# Because He Lives added with song_id 738
# Christ The Lord Is Risen Today added with song_id 739
# Crown Him with Many Crowns added with song_id 740
# Up From The Grave added with song_id 741
# All Hail The Power of Jesus Name added with song_id 742
# All Glory Laud And Honor added with song_id 743
# Be Still My Soul added with song_id 744
# East / West (Psalm 103) added with song_id 745
# Dust We Are And Shall Return added with song_id 746
# From the Dust added with song_id 747
# How Great Thou Art added with song_id 748
# Before the Throne of God Above added with song_id 749
# What a Friend We Have In Jesus added with song_id 750
# Holy Holy Holy added with song_id 751
# You Are Holy (Prince Of Peace) added with song_id 752
# Angels From The Realms of Glory added with song_id 753
# Behold The Lamb of God added with song_id 754
# Hallelujah! Christ Is Coming added with song_id 755
# O Come All Ye Faithful added with song_id 756
# O Little Town of Bethlehem added with song_id 757
# Angels We Have Heard On High added with song_id 758
# Come Thou Long Expected Jesus added with song_id 759
# Even So Come added with song_id 760
# O Come O Come Emmanuel added with song_id 761
# The First Noel added with song_id 762
# There Is A Redeemer added with song_id 763
# Wounded For Me added with song_id 764
# This is My Father's World added with song_id 765
# All in All added with song_id 766
# Calvary Cover's It All added with song_id 767
# The Wonderful/wondrous Cross added with song_id 768
# Lead Me To The Cross added with song_id 769
# To God Be The Glory added with song_id 770
# Turn Your Eyes upon Jesus added with song_id 771
# The Old Rugged Cross added with song_id 772
# I stand in awe of you added with song_id 773
# Praise to the Lord, The Almighty added with song_id 774
# I Surrender All added with song_id 775
# Who Am I added with song_id 776
# There Will Be Rest added with song_id 777
# Spirit of The Living God added with song_id 778
# The Potter's Hand added with song_id 779
# Day By Day added with song_id 780
# The Stand added with song_id 781
# Behold Him added with song_id 782
# The Power of Your Love added with song_id 783
# Hallelujah What a Savior - Traditional added with song_id 784
# O Sacred Head Now wounded added with song_id 785
# Passover Song  added with song_id 786
# The Power Of The Cross added with song_id 787
# Moment By Moment added with song_id 788
# Lord Have Mercy added with song_id 789
# Sweetly Broken added with song_id 790
# Here I Am To Worship added with song_id 791
# God With Us added with song_id 792
# His Name Shall Be added with song_id 793
# Give Me Jesus added with song_id 794
# Glorious Day added with song_id 795
# Through It All (hymn) added with song_id 796
# Great I Am added with song_id 797
# By Thy Mercy added with song_id 798
# Like a Lamb who needs the shepherd added with song_id 799

# %% [markdown]
# # Create Sets and add songs within those sets.

# %%
import datetime
import calendar

# set_ids = {}
cnx = get_cnx()
try :
    for date in df.loc[:, FIRST_SET:LAST_SET]:
        month = int(date[:date.find("/")])
        day = int(date[date.find("/") + 1: date.rfind("/")])
        year = int(date[date.rfind("/") + 1:])
        intDay = datetime.date(year=year, month=month, day=day).weekday()
        dayOfTheWeek = calendar.day_name[intDay]

        
        # Get a cursor
        cur = cnx.cursor(prepared=True)
        # Check to see if song already exists
        cur.execute("""SELECT setlist_id FROM setlist
            WHERE date = STR_TO_DATE(%s, '%m/%d/%Y') AND band_id = %s LIMIT 1""", (date,BAND_ID))
        rows = cur.fetchall()
        if rows:
            print(date, "already exists with setlist_id", rows[0][0])
            # set_ids[date] = rows[0][0]
        else :
            # Parse relevant data
            
    
            # Execute a query to create the set
            cur.execute("""INSERT INTO setlist 
                        (name, date, creator_id, band_id)
                        VALUES (%s, STR_TO_DATE(%s, '%m/%d/%Y'), %s, %s)""",
                       (dayOfTheWeek + " Service", date, USER_ID, BAND_ID))
            # Save the song_id for later
            setlist_id = cur.lastrowid
            # set_ids[date] = setlist_id
            print(date, "added with setlist_id", cur.lastrowid)

            # Add songs to the set
            set_col = df[date]
            songs = set_col[set_col.notnull()]
            songs_sorted = songs.sort_values(ascending=True)
            for song, song_set_value in songs_sorted.items():
                song_id = song_ids[song]
                print ("\t", song, song_id, song_set_value)
                cur.execute("""INSERT INTO setlist_song 
                                (setlist_id, setlist_order, song_id, note)
                                select ?, COUNT(*), ?, ? from setlist_song where setlist_id = ?""",
                                   (setlist_id, song_id, song_set_value, setlist_id))
            
        # Make sure data is committed to the database
        cnx.commit()
        cur.close()
except Exception as e:
    raise e
finally:
    # Close connection
    cnx.close()
# Out:
# 7/4/2021 added with setlist_id 175
# 	 Jesus Paid it All 698 x
# 	 O Come to the Altar 699 x
# 	 Never See the End 706 x
# 	 What A Beautiful Name 719 x
# 7/11/2021 added with setlist_id 176
# 	 Death Was Arrested 647 x
# 	 Living Hope 652 x
# 	 Lord I Need You 662 x
# 	 By Thy Mercy 798 x
# 7/18/2021 added with setlist_id 177
# 	 Our God Is With Us 685 x
# 	 Forever Reign 686 x
# 	 Great I Am 797 x
# 7/25/2021 added with setlist_id 178
# 	 He Will Hold Me Fast 712 x
# 	 Glorious Day 795 x
# 	 Through It All (hymn) 796 x
# 8/1/2021 added with setlist_id 179
# 	 How Deep The Father's Love 702 x
# 	 Come Thou Fount 704 x
# 	 Reckless Love 713 x
# 	 Who You Say I Am 728 x
# 8/8/2021 added with setlist_id 180
# 	 Everlasting God 665 x
# 	 From The Inside Out 722 x
# 	 The Potter's Hand 779 x
# 8/15/2021 added with setlist_id 181
# 	 Blessed Be Your Name 707 x
# 	 Hosanna (Praise Is Rising) 718 x
# 	 What A Beautiful Name 719 x
# 8/22/2021 added with setlist_id 182
# 	 Our God Is With Us 685 x
# 	 This Time I Will Bring Praise 705 x
# 	 Great Is Thy Faithfulness 714 x
# 9/5/2021 added with setlist_id 183
# 	 Cornerstone 644 x
# 	 Never See the End 706 x
# 	 Reckless Love 713 x
# 8/29/2021 added with setlist_id 184
# 	 The Lion and the Lamb 651 x
# 	 In Christ Alone 657 x
# 	 Better is One Day 694 x
# 	 Table of Plenty 721 x
# 9/12/2021 added with setlist_id 185
# 	 Living Hope 652 x
# 	 Facing a Task Unfinished 671 x
# 	 O Come to the Altar 699 x
# 	 This is Amazing Grace 711 x
# 9/19/2021 added with setlist_id 186
# 	 Cornerstone 644 x
# 	 This I Believe (The Creed) 645 x
# 	 Build My Life 656 x
# 9/26/2021 added with setlist_id 187
# 	 Is He Worthy 691 song3
# 	 Lord I Need You 662 x
# 	 Indescribable 666 x
# 	 Open The Eyes Of My Heart 682 x
# 	 Be Thou My Vision 736 x
# 10/3/2021 added with setlist_id 188
# 	 Death Was Arrested 647 1
# 	 Forever Reign 686 2
# 	 Never See the End 706 3
# 	 All The People Said Amen 725 4
# 	 Build Your Kingdom Here 670 x
# 10/10/2021 added with setlist_id 189
# 	 Take My Life (and Let It Be) 659 Hymn
# 	 O For A Thousand Tongues 683 Open
# 	 Oceans 727 SOR
# 	 What A Beautiful Name 719 Song 1
# 	 Way Maker 653 Song 2
# 10/17/2021 added with setlist_id 190
# 	 Before the Throne of God Above 749 Hymn
# 	 The Lion and the Lamb 651 Open
# 	 Our God Is With Us 685 SOR
# 	 Everlasting God 665 Song 2
# 	 This Time I Will Bring Praise 705 Song 3
# 10/24/2021 added with setlist_id 191
# 	 How Great Is Our God 681 x
# 	 O Praise The Name (Anástasis) 689 x
# 	 Blessed Be Your Name 707 x
# 	 Hosanna (Praise Is Rising) 718 x
# 10/31/2021 added with setlist_id 192
# 	 Who You Say I Am 728 2
# 	 He Will Hold Me Fast 712 3
# 	 Dance Again 650 4
# 	 Broken Vessels (Amazing Grace) 717 5
# 11/7/2021 added with setlist_id 193
# 	 Our God 669 1
# 	 Revelation Song 720 2
# 	 Before the Throne of God Above 749 3
# 	 Facing a Task Unfinished 671 4
# 11/14/2021 added with setlist_id 194
# 	 Your Grace Is Enough 674 1?
# 	 You Are Holy (Prince Of Peace) 752 2?
# 	 Who Am I 776 3?
# 	 Give Me Jesus 794 SOR?
# 11/21/2021 added with setlist_id 195
# 	 What A Beautiful Name 719 1
# 	 Tis So Sweet to Trust in Jesus 687 2
# 	 O Come to the Altar 699 3
# 	 Do It Again 733 4
# 11/28/2021 added with setlist_id 196
# 	 His Name Shall Be 793 1
# 	 Hallelujah! Christ Is Coming 755 2
# 	 Even So Come 760 3
# 12/5/2021 added with setlist_id 197
# 	 Dance Again 650 1
# 	 The Lion and the Lamb 651 3
# 	 Our God Is With Us 685 4
# 	 Cornerstone 644 ?
# 12/12/2021 added with setlist_id 198
# 	 Is He Worthy 691 2
# 	 God With Us 792 2
# 12/19/2021 added with setlist_id 199
# 	 Hallelujah! Christ Is Coming 755 2
# 	 Hosanna (I See The King of Glory) 668 3
# 	 Angels From The Realms of Glory 753 X
# 12/26/2021 added with setlist_id 200
# 1/2/2022 added with setlist_id 201
# 	 All Creatures of Our God and King 690 X
# 	 This Time I Will Bring Praise 705 X
# 	 What A Beautiful Name 719 X
# 	 Behold Him 782 X
# 	 Shine Jesus Shine 726 x
# 1/9/2022 added with setlist_id 202
# 	 Way Maker 653 X
# 	 Our God 669 X
# 	 How Deep The Father's Love 702 X
# 	 Reckless Love 713 X
# 	 Here I Am To Worship 791 X
# 1/16/2022 added with setlist_id 203
# 	 Death Was Arrested 647 X
# 	 Open The Eyes Of My Heart 682 X
# 	 O Praise The Name (Anástasis) 689 X
# 	 The Wonderful/wondrous Cross 768 X
# 	 Turn Your Eyes upon Jesus 771 X
# 1/23/2022 added with setlist_id 204
# 	 In Christ Alone 657 2
# 	 Amazing Grace (My Chains Are Gone) 730 3
# 	 Better is One Day 694 Open
# 1/30/2022 added with setlist_id 205
# 	 Dance Again 650 X
# 	 Lord I Need You 662 X
# 	 He Will Hold Me Fast 712 X
# 	 Great Is Thy Faithfulness 714 X
# 2/6/2022 added with setlist_id 206
# 	 A Mighty Fortress  715 Hymn
# 	 There Will Be Rest 777 Special Music
# 	 Hosanna (I See The King of Glory) 668 X
# 	 How Great Is Our God 681 X
# 	 10,000 Reasons 688 X
# 	 Broken Vessels (Amazing Grace) 717 X
# 2/13/2022 added with setlist_id 207
# 	 Come Thou Fount 704 Hymn
# 	 Your Grace Is Enough 674 X
# 	 Never See the End 706 X
# 	 This is Amazing Grace 711 X
# 	 Table of Plenty 721 X
# 2/20/2022 added with setlist_id 208
# 	 Build My Life 656 1
# 	 O For A Thousand Tongues 683 2
# 	 From The Inside Out 722 3
# 	 To God Be The Glory 770 Hymn
# 	 Indescribable 666 Open
# 2/27/2022 added with setlist_id 209
# 	 Jesus Paid it All 698 1
# 	 Before the Throne of God Above 749 2
# 	 The Stand 781 3
# 	 Reckless Love 713 Open?
# 3/6/2022 added with setlist_id 210
# 	 Blessed Be Your Name 707 1
# 	 Our God Is With Us 685 2
# 	 Create In Me A clean heart 701 4
# 	 Lord Have Mercy 789 CON
# 	 Here I Am To Worship 791 Open
# 	 It Is Well with My Soul 708 hymn
# 3/13/2022 added with setlist_id 211
# 	 Graves into Gardens 697 1
# 	 Lead Me To The Cross 769 2
# 	 Take My Life (and Let It Be) 659 3
# 	 Sweetly Broken 790 Confessional
# 	 This I Believe (The Creed) 645 Open
# 3/20/2022 added with setlist_id 212
# 	 How Deep The Father's Love 702 1
# 	 Lord Have Mercy 789 2
# 	 Reckless Love 713 3
# 	 Forever Reign 686 open
# 	 The Greatest Commandment 673 response
# 3/27/2022 added with setlist_id 213
# 	 Death Was Arrested 647 1
# 	 A Mighty Fortress  715 2
# 	 Graves into Gardens 697 3
# 	 Living Hope 652 4
# 	 Moment By Moment 788 hymn
# 4/3/2022 added with setlist_id 214
# 	 Praise to the Lord, The Almighty 774 Hymn?
# 	 The Lion and the Lamb 651 X
# 	 Forever (We Sing Hallelujah) 680 X
# 	 Is He Worthy 691 X
# 	 What A Beautiful Name 719 X
# 4/10/2022 added with setlist_id 215
# 	 All Hail The Power of Jesus Name 742 Hymn
# 	 Hosanna (I See The King of Glory) 668 X
# 	 All Creatures of Our God and King 690 X
# 	 Hosanna (Praise Is Rising) 718 X
# 4/15/2022 added with setlist_id 216
# 	 The Wonderful/wondrous Cross 768 (Instr.)
# 	 Passover Song  786 Special
# 	 How Deep The Father's Love 702 X
# 	 Lead Me To The Cross 769 X
# 	 The Old Rugged Cross 772 X
# 	 Hallelujah What a Savior - Traditional 784 X
# 	 O Sacred Head Now wounded 785 X
# 	 The Power Of The Cross 787 X
# 4/17/2022 added with setlist_id 217
# 	 Because He Lives 738 Choir
# 	 Crown Him with Many Crowns 740 Hymn
# 	 Living Hope 652 X
# 	 O Praise The Name (Anástasis) 689 X
# 	 Graves into Gardens 697 X
# 	 Christ The Lord Is Risen Today 739 X
# 	 Up From The Grave 741 X
# 4/24/2022 added with setlist_id 218
# 	 Behold Him 782 1
# 	 Revelation Song 720 2
# 	 The Power of Your Love 783 3
# 	 It Is Well with My Soul 708 Hymn
# 	 Open The Eyes Of My Heart 682 Open
# 5/1/2022 added with setlist_id 219
# 	 Death Was Arrested 647 X
# 	 Indescribable 666 X
# 	 This is Amazing Grace 711 X
# 	 From The Inside Out 722 X
# 	 Rock of ages 731 hymn
# 5/8/2022 added with setlist_id 220
# 	 Our God 669 X
# 	 This Time I Will Bring Praise 705 X
# 	 Blessed Be Your Name 707 X
# 	 The Stand 781 X
# 	 Day By Day 780 hymn
# 5/15/2022 added with setlist_id 221
# 	 Great Is Thy Faithfulness 714 Hymn
# 	 In Christ Alone 657 X
# 	 Our God Is With Us 685 X
# 	 Never See the End 706 X
# 5/22/2022 added with setlist_id 222
# 	 Cornerstone 644 X
# 	 The Potter's Hand 779 X
# 	 A Mighty Fortress  715 hymn
# 	 Way Maker 653 x
# 	 O Come to the Altar 699 x
# 5/29/2022 added with setlist_id 223
# 	 Be Thou My Vision 736 1
# 	 All The People Said Amen 725 2
# 	 The Greatest Commandment 673 3
# 	 Facing a Task Unfinished 671 4
# 6/5/2022 added with setlist_id 224
# 	 Everlasting God 665 1
# 	 Lord of Hosts (Psalm 46) 716 2
# 	 Do It Again 733 3
# 	 He Will Hold Me Fast 712 4
# 6/12/2022 added with setlist_id 225
# 	 Spirit of The Living God 778 Hymn
# 	 Great Is Thy Faithfulness 714 Open
# 	 The Lion and the Lamb 651 X
# 	 Build My Life 656 X
# 	 Your Will Be Done 664 X
# 6/19/2022 added with setlist_id 226
# 	 Holy Holy Holy 751 Hymn?
# 	 Is He Worthy 691 X
# 	 As The Deer 709 X
# 	 What A Beautiful Name 719 X
# 	 You Are Holy (Prince Of Peace) 752 X
# 6/26/2022 added with setlist_id 227
# 	 How Great Is Our God 681 Star Lake
# 	 Open The Eyes Of My Heart 682 Star Lake
# 7/3/2022 added with setlist_id 228
# 	 The Wonderful/wondrous Cross 768 Hymn
# 	 Mighty To Save 654 X
# 	 Days of Elijah 675 X
# 	 O Praise The Name (Anástasis) 689 X
# 	 Hosanna (Praise Is Rising) 718 X
# 7/10/2022 added with setlist_id 229
# 	 There Will Be Rest 777 Response
# 	 Cornerstone 644 X
# 	 It Is Well with My Soul 708 X
# 	 Lord of Hosts (Psalm 46) 716 X
# 	 Who Am I 776 X
# 7/17/2022 added with setlist_id 230
# 	 I Surrender All 775 Response
# 	 Living Hope 652 X
# 	 Facing a Task Unfinished 671 X
# 	 We Will Feast In The House of Zion 696 X
# 	 Praise to the Lord, The Almighty 774 X
# 7/24/2022 added with setlist_id 231
# 	 I stand in awe of you 773 Response
# 	 This I Believe (The Creed) 645 X
# 	 Shout to the Lord 658 X
# 	 How Deep The Father's Love 702 X
# 	 Shine Jesus Shine 726 X
# 7/31/2022 added with setlist_id 232
# 	 The Old Rugged Cross 772 Response
# 	 Our God 669 X
# 	 Your Grace Is Enough 674 X
# 	 Egypt 692 X
# 	 What A Beautiful Name 719 X
# 8/7/2022 added with setlist_id 233
# 	 We Will Feast In The House of Zion 696 1
# 	 All Creatures of Our God and King 690 2
# 	 Good Good Father 723 3
# 	 Who You Say I Am 728 4
# 	 Reckless Love 713 Response
# 8/14/2022 added with setlist_id 234
# 	 Jesus Paid it All 698 1
# 	 Death Was Arrested 647 2
# 	 Before the Throne of God Above 749 3
# 	 Never See the End 706 4
# 	 Amazing Grace (My Chains Are Gone) 730 Hymn
# 8/21/2022 added with setlist_id 235
# 	 A Mighty Fortress  715 1
# 	 Forever Reign 686 2
# 	 Same God 732 3
# 	 Great Is Thy Faithfulness 714 Hymn
# 	 He Will Hold Me Fast 712 Sor
# 8/28/2022 added with setlist_id 236
# 	 O For A Thousand Tongues 683 1
# 	 All The People Said Amen 725 2
# 	 How Great Is Our God 681 3
# 	 Forever (We Sing Hallelujah) 680 4
# 	 Behold the Lamb (Communion) 648 Communion
# 	 The Church's One Foundation 724 Hymn
# 9/4/2022 added with setlist_id 237
# 	 Tis So Sweet to Trust in Jesus 687 2
# 	 Come Thou Fount 704 3
# 	 Our God Is With Us 685 4
# 	 Turn Your Eyes upon Jesus 771 Hymn
# 9/11/2022 added with setlist_id 238
# 	 Egypt 692 1
# 	 Be Thou My Vision 736 2
# 	 Broken Vessels (Amazing Grace) 717 3
# 	 Build Your Kingdom Here 670 4
# 9/18/2022 added with setlist_id 239
# 	 Holy Holy Holy 751 1
# 	 Same God 732 2
# 	 Is He Worthy 691 3
# 	 How Deep The Father's Love 702 4
# 9/25/2022 added with setlist_id 240
# 	 To God Be The Glory 770 1
# 	 Graves into Gardens 697 2
# 	 Because He Lives 738 3
# 	 Living Hope 652 4
# 	 I Love To Tell The Story 660 Hymn
# 	 Let it be so with your church 672 Special
# 10/2/2022 added with setlist_id 241
# 	 As The Deer 709 1
# 	 This is Amazing Grace 711 2
# 	 Mighty To Save 654 3
# 	 What A Beautiful Name 719 4
# 	 The Solid Rock 663 Hymn
# 10/9/2022 added with setlist_id 242
# 	 Grace Greater Than All Our Sin 729 Hymn
# 	 Cornerstone 644 X
# 	 This I Believe (The Creed) 645 X
# 	 Build My Life 656 X
# 	 O Praise The Name (Anástasis) 689 X
# 10/16/2022 added with setlist_id 243
# 	 Lead Me To The Cross 769 1
# 	 Lord I Need You 662 2
# 	 From The Inside Out 722 3
# 	 He Will Hold Me Fast 712 4
# 	 Take My Life (and Let It Be) 659 Hymn
# 10/23/2022 added with setlist_id 244
# 	 Jesus Paid it All 698 1
# 	 Indescribable 666 2
# 	 God So Loved 667 3
# 	 In Christ Alone 657 4
# 	 Tis So Sweet to Trust in Jesus 687 Hymn
# 10/30/2022 added with setlist_id 245
# 	 The Wonderful/wondrous Cross 768 1
# 	 God So Loved 667 2
# 	 O Come to the Altar 699 3
# 	 Behold the Lamb (Communion) 648 4
# 	 How Deep The Father's Love 702 Ellen - Communion
# 	 All in All 766 Ellen - Communion
# 	 Calvary Cover's It All 767 Hymn
# 11/06/2022 added with setlist_id 246
# 	 How Great Thou Art 748 1
# 	 Everlasting God 665 2
# 	 This I Believe (The Creed) 645 3
# 	 Good Good Father 723 4
# 	 This is My Father's World 765 Hymn
# 11/13/2022 added with setlist_id 247
# 	 Amazing Grace (My Chains Are Gone) 730 1
# 	 Your Grace Is Enough 674 2
# 	 Egypt 692 3
# 	 Living Hope 652 4
# 	 Wounded For Me 764 Hymn
# 11/20/2022 added with setlist_id 248
# 	 This I Believe (The Creed) 645 1
# 	 Death Was Arrested 647 2
# 	 Shine Jesus Shine 726 3
# 	 There Is A Redeemer 763 4
# 	 O For A Thousand Tongues 683 Hymn
# 11/27/2022 added with setlist_id 249
# 	 The First Noel 762 1
# 	 Hallelujah! Christ Is Coming 755 2
# 	 Even So Come 760 3
# 	 Angels We Have Heard On High 758 4
# 	 O Come O Come Emmanuel 761 Candle
# 	 Come Thou Long Expected Jesus 759 Hymn
# 12/4/2022 added with setlist_id 250
# 	 O Little Town of Bethlehem 757 Candle
# 	 Hosanna (I See The King of Glory) 668 X
# 	 Our God Is With Us 685 X
# 	 Before the Throne of God Above 749 X
# 	 O Come All Ye Faithful 756 X
# 12/11/2022 added with setlist_id 251
# 	 Behold The Lamb of God 754 Special
# 	 The Lion and the Lamb 651 X
# 	 God So Loved 667 X
# 	 Is He Worthy 691 X
# 	 Hallelujah! Christ Is Coming 755 X
# 12/18/2022 added with setlist_id 252
# 	 Angels From The Realms of Glory 753 X
# 1/1/2023 added with setlist_id 253
# 	 How Great Is Our God 681 Response
# 	 Mighty To Save 654 X
# 	 Our God 669 X
# 	 O Praise The Name (Anástasis) 689 X
# 	 Hosanna (Praise Is Rising) 718 X
# 1/8/2023 added with setlist_id 254
# 	 Holy Holy Holy 751 Hymn
# 	 All Creatures of Our God and King 690 Open
# 	 Shout to the Lord 658 X
# 	 What A Beautiful Name 719 X
# 	 You Are Holy (Prince Of Peace) 752 X
# 1/15/2023 added with setlist_id 255
# 	 The Greatest Commandment 673 Hymn
# 	 Cornerstone 644 X
# 	 Build My Life 656 X
# 	 Let it be so with your church 672 X
# 	 This is Amazing Grace 711 X
# 1/22/2023 added with setlist_id 256
# 	 Facing a Task Unfinished 671 Hymn
# 	 The Lord's Prayer (It's Yours) 655 X
# 	 Build Your Kingdom Here 670 X
# 	 Reckless Love 713 X
# 	 Be Thou My Vision 736 X
# 1/29/2023 added with setlist_id 257
# 	 Table of Plenty 721 Communion
# 	 Great Is Thy Faithfulness 714 Hymn
# 	 Way Maker 653 X
# 	 The Lord's Prayer (It's Yours) 655 X
# 	 Blessed Be Your Name 707 X
# 	 It Is Well with My Soul 708 X
# 12/25/2022 added with setlist_id 258
# 2/5/2023 added with setlist_id 259
# 	 Jesus Paid it All 698 Hymn
# 	 Living Hope 652 X
# 	 The Lord's Prayer (It's Yours) 655 X
# 	 Egypt 692 X
# 	 Come Thou Fount 704 X
# 2/12/2023 added with setlist_id 260
# 	 A Mighty Fortress  715 Hymn
# 	 The Lord's Prayer (It's Yours) 655 X
# 	 Lord I Need You 662 X
# 	 Before the Throne of God Above 749 X
# 	 What a Friend We Have In Jesus 750 X
# 2/19/2023 added with setlist_id 261
# 	 Cornerstone 644 X
# 	 Forever Reign 686 X
# 	 Graves into Gardens 697 X
# 	 How Great Thou Art 748 X
# 2/22/2023 added with setlist_id 262
# 	 Purify My Heart (Psalm 19) 661 X
# 	 Create In Me A clean heart 701 X
# 	 Because He Lives 738 X
# 	 Dust We Are And Shall Return 746 X
# 	 From the Dust 747 X
# 2/26/2023 added with setlist_id 263
# 	 East / West (Psalm 103) 745 Comm
# 	 Nothing But The Blood 700 Hymn
# 	 Purify My Heart (Psalm 19) 661 X
# 	 Never See the End 706 X
# 	 All The People Said Amen 725 X
# 	 Same God 732 X
# 3/5/2023 added with setlist_id 264
# 	 Savior Like a Shepherd Lead Us 695 Hymn
# 	 God So Loved 667 X
# 	 Better is One Day 694 X
# 	 This Time I Will Bring Praise 705 X
# 	 Broken Vessels (Amazing Grace) 717 X
# 3/12/2023 added with setlist_id 265
# 	 O For A Thousand Tongues 683 Hymn
# 	 The Lion and the Lamb 651 X
# 	 Our God 669 X
# 	 Open The Eyes Of My Heart 682 X
# 	 Lord of Hosts (Psalm 46) 716 X
# 3/19/2023 added with setlist_id 266
# 	 This I Believe (The Creed) 645 X
# 	 Reckless Love 713 X
# 	 Good Good Father 723 X
# 	 Who You Say I Am 728 X
# 3/26/2023 added with setlist_id 267
# 	 We Will Feast In The House of Zion 696 Communion
# 	 It Is Well with My Soul 708 Hymn
# 	 As The Deer 709 X
# 	 King of Kings 710 X
# 	 Oceans 727 X
# 	 Be Still My Soul 744 X
# 4/2/2023 added with setlist_id 268
# 	 All Glory Laud And Honor 743 Hymn
# 	 Hosanna (I See The King of Glory) 668 X
# 	 All Creatures of Our God and King 690 X
# 	 Hosanna (Praise Is Rising) 718 X
# 	 All Hail The Power of Jesus Name 742 X
# 4/9/2023 added with setlist_id 269
# 	 In Christ Alone 657 X
# 	 Forever (We Sing Hallelujah) 680 X
# 	 Christ The Lord Is Risen Today 739 X
# 	 Is He Worthy 691 choir
# 	 Crown Him with Many Crowns 740 choir
# 	 Up From The Grave 741 hymn
# 4/16/2023 added with setlist_id 270
# 	 Make Me A Blessing 737 Hymn
# 	 Cornerstone 644 x
# 	 Death Was Arrested 647 x
# 	 O Praise The Name (Anástasis) 689 x
# 	 Because He Lives 738 x
# 4/23/2023 added with setlist_id 271
# 	 Great Is Thy Faithfulness 714 Hymn
# 	 Living Hope 652 X
# 	 Way Maker 653 X
# 	 Our God Is With Us 685 X
# 	 Be Thou My Vision 736 X
# 4/30/2023 added with setlist_id 272
# 	 Jesus Loves Even Me 735 Hymn
# 	 God So Loved 667 X
# 	 O Come to the Altar 699 X
# 	 How Deep The Father's Love 702 X
# 	 Reckless Love 713 X
# 5/7/2023 added with setlist_id 273
# 	 He Will Hold Me Fast 712 X
# 	 A Mighty Fortress  715 X
# 	 Same God 732 X
# 	 Do It Again 733 X
# 	 Standing on the Promises 734 X
# 5/14/2023 added with setlist_id 274
# 	 Jesus Paid it All 698 X
# 	 King of Kings 710 X
# 	 This is Amazing Grace 711 X
# 	 Amazing Grace (My Chains Are Gone) 730 X
# 	 Rock of ages 731 X
# 5/21/2023 added with setlist_id 275
# 	 This I Believe (The Creed) 645 X
# 	 Behold the Lamb (Communion) 648 X
# 	 The Lord's Prayer (It's Yours) 655 X
# 	 God So Loved 667 X
# 	 The Church's One Foundation 724 X
# 	 Grace Greater Than All Our Sin 729 X
# 5/28/2023 added with setlist_id 276
# 	 Cornerstone 644 X
# 	 Indescribable 666 X
# 	 How Great Is Our God 681 X
# 	 Oceans 727 X
# 	 Who You Say I Am 728 X
# 6/4/2023 added with setlist_id 277
# 	 Shine Jesus Shine 726 Hymn
# 	 House Of The Lord 693 X
# 	 We Will Feast In The House of Zion 696 X
# 	 Graves into Gardens 697 X
# 	 All The People Said Amen 725 X
# 6/11/2023 added with setlist_id 278
# 	 The Church's One Foundation 724 Hymn
# 	 The Lion and the Lamb 651 X
# 	 Purify My Heart (Psalm 19) 661 X
# 	 Lord I Need You 662 X
# 	 This Time I Will Bring Praise 705 X
# 6/18/2023 added with setlist_id 279
# 	 Build My Life 656 X
# 	 Come Thou Fount 704 X
# 	 From The Inside Out 722 X
# 	 Good Good Father 723 X
# 6/25/2023 added with setlist_id 280
# 	 All Creatures of Our God and King 690 X
# 	 House Of The Lord 693 X
# 	 What A Beautiful Name 719 X
# 	 Revelation Song 720 X
# 	 Table of Plenty 721 X
# 7/2/2023 added with setlist_id 281
# 	 The Lord's Prayer (It's Yours) 655 X
# 	 In Christ Alone 657 X
# 	 O Praise The Name (Anástasis) 689 X
# 	 Hosanna (Praise Is Rising) 718 X
# 7/9/2023 added with setlist_id 282
# 	 Everlasting God 665 X
# 	 A Mighty Fortress  715 X
# 	 Lord of Hosts (Psalm 46) 716 X
# 	 Broken Vessels (Amazing Grace) 717 X
# 7/16/2023 added with setlist_id 283
# 	 Great Is Thy Faithfulness 714 Hymn
# 	 King of Kings 710 X
# 	 This is Amazing Grace 711 X
# 	 He Will Hold Me Fast 712 X
# 	 Reckless Love 713 X
# 7/23/2023 added with setlist_id 284
# 	 It Is Well with My Soul 708 Hymn
# 	 This Time I Will Bring Praise 705 X
# 	 Never See the End 706 X
# 	 Blessed Be Your Name 707 X
# 	 As The Deer 709 X
# 7/30/2023 added with setlist_id 285
# 	 Come Thou Fount 704 Hymn
# 	 Goodness of God 646 X
# 	 O Praise The Name (Anástasis) 689 X
# 	 How Deep The Father's Love 702 X
# 	 His Mercy is More 703 X
# 8/6/2023 added with setlist_id 286
# 	 O Come to the Altar 699 1
# 	 Jesus Paid it All 698 2
# 	 Graves into Gardens 697 3
# 	 Create In Me A clean heart 701 4
# 	 Nothing But The Blood 700 Hymn
# 8/13/2023 added with setlist_id 287
# 	 Savior Like a Shepherd Lead Us 695 Hymn
# 	 Goodness of God 646 X
# 	 House Of The Lord 693 X
# 	 Better is One Day 694 X
# 	 We Will Feast In The House of Zion 696 X
# 8/20/2023 added with setlist_id 288
# 	 O Praise The Name (Anástasis) 689 X
# 	 All Creatures of Our God and King 690 X
# 	 Is He Worthy 691 X
# 	 Egypt 692 X
# 8/27/2023 added with setlist_id 289
# 	 10,000 Reasons 688 1
# 	 Tis So Sweet to Trust in Jesus 687 2
# 	 Forever Reign 686 3
# 	 Our God Is With Us 685 4
# 	 Like a Lamb who needs the shepherd 799 Hymn
# 9/3/2023 added with setlist_id 290
# 	 Open The Eyes Of My Heart 682 1
# 	 How Great Is Our God 681 2
# 	 Forever (We Sing Hallelujah) 680 3
# 	 The Blessing 684 4
# 	 O For A Thousand Tongues 683 Hymn
# 9/10/2023 added with setlist_id 291
# 	 Indescribable 666 1
# 	 God So Loved 667 2
# 	 Days of Elijah 675 3
# 	 Hosanna (I See The King of Glory) 668 4
# 	 Shine Jesus Shine 726 Hymn
# 	 Let it be so with your church 672 Special
# 9/17/2023 added with setlist_id 292
# 	 The Lord's Prayer (It's Yours) 655 X
# 	 Build My Life 656 X
# 	 In Christ Alone 657 X
# 	 Shout to the Lord 658 X
# 	 Take My Life (and Let It Be) 659 X
